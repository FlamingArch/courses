# %% [markdown]
# # freeCodeCamp | Data Analysis with Python
# **Youtube Link: https://www.youtube.com/watch?v=r-uOLxNrNk8&list=PL1jB36QHTjD2FjMC-ReFgwVyHMTDlMCU7&index=2**

# %% [markdown]
# # What is Data Analysis

# %% [markdown]
# A process of **inspecting, cleansing, transforming** and **modeling data** with the goal of discovering useful information, informing conclusion and support decision-making.

# %% [markdown]
# ## Data Analysis Tools
# There are two types of tools available for data analysis:
# - **Auto Managed Closed Tools** (Example: Excel, Tableau, looker, etc.)
# - **Programing Languages / Open Tools** (Example: Python, R, Julia)

# %% [markdown]
# ## Data Analysis Process
# 1. Data Extraction
# 2. Data Cleaning
# 3. Data Wrangling
# 4. Analysis
# 5. Action

# %% [markdown]
# ## Data Scientist vs Data Analyst

# %% [markdown]
# ![Screenshot 2020-09-09 at 6.19.24 PM.png](attachment:a5e1ac68-3337-4ec6-b62c-af8350307cfb.png)

# %% [markdown]
# ## Common Tools

# %% [markdown]
# ![Screenshot 2020-09-09 at 6.20.48 PM.png](attachment:f3d4c86a-f6ec-4efa-b6d6-0d8714b2d298.png)

# %% [markdown]
# # Real-Life Example of Python

# %% [markdown]
# ## Importing Data

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
sales_data = pd.read_csv('sales_data.csv', parse_dates=['Date'])
sales_data.shape
# Out:
# (113036, 18)

# %% [markdown]
# #### Information about data

# %%
sales_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 113036 entries, 0 to 113035
# Data columns (total 18 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Date              113036 non-null  datetime64[ns]
#  1   Day               113036 non-null  int64
#  2   Month             113036 non-null  object
#  3   Year              113036 non-null  int64
#  4   Customer_Age      113036 non-null  int64
#  5   Age_Group         113036 non-null  object
#  6   Customer_Gender   113036 non-null  object
#  7   Country           113036 non-null  object
#  8   State             113036 non-null  object
#  9   Product_Category  113036 non-null  object
#  10  Sub_Category      113036 non-null  object
#  11  Product           113036 non-null  object
#  12  Order_Quantity    113036 non-null  int64
#  13  Unit_Cost         113036 non-null  int64
#  14  Unit_Price        113036 non-null  int64
#  15  Profit            113036 non-null  int64
# ...

# %% [markdown]
# #### Description of Data

# %% [markdown]
# Describing entire dataset:

# %%
sales_data.describe()
# Out:
#                  Day           Year   Customer_Age  Order_Quantity  \
# count  113036.000000  113036.000000  113036.000000   113036.000000
# mean       15.665753    2014.401739      35.919212       11.901660
# std         8.781567       1.272510      11.021936        9.561857
# min         1.000000    2011.000000      17.000000        1.000000
# 25%         8.000000    2013.000000      28.000000        2.000000
# 50%        16.000000    2014.000000      35.000000       10.000000
# 75%        23.000000    2016.000000      43.000000       20.000000
# max        31.000000    2016.000000      87.000000       32.000000
#
#            Unit_Cost     Unit_Price         Profit           Cost  \
# count  113036.000000  113036.000000  113036.000000  113036.000000
# mean      267.296366     452.938427     285.051665     469.318695
# std       549.835483     922.071219     453.887443     884.866118
# min         1.000000       2.000000     -30.000000       1.000000
# ...

# %% [markdown]
# Describing Particular Column

# %%
sales_data['Day'].describe()
# Out:
# count    113036.000000
# mean         15.665753
# std           8.781567
# min           1.000000
# 25%           8.000000
# 50%          16.000000
# 75%          23.000000
# max          31.000000
# Name: Day, dtype: float64

# %%
sales_data['Day'].mean()
# Out:
# 15.665752503627163

# %%
sales_data['Day'].median()
# Out:
# 16.0

# %% [markdown]
# ## Plotting Dataframe

# %%
sales_data['Unit_Price'].plot(kind='box', vert=False, figsize=(14,6))

# %%
sales_data['Unit_Price'].plot(kind='density', figsize=(14,6))

# %%
ax = sales_data['Unit_Cost'].plot(kind='density', figsize=(14,6))
ax.axvline(sales_data['Unit_Cost'].mean(), color='red')
ax.axvline(sales_data['Unit_Cost'].median(), color='green')

# %%
ax = sales_data['Unit_Cost'].plot(kind='hist', figsize=(14,6))
ax.set_xlabel('Number of sales')
ax.set_ylabel('Dollars')
# Out:
# Text(0, 0.5, 'Dollars')

# %% [markdown]
# ## Catrgorical Analysis and Visualisation

# %%
n = sales_data['Age_Group'].value_counts()
n
# Out:
# Adults (35-64)          55824
# Young Adults (25-34)    38654
# Youth (<25)             17828
# Seniors (64+)             730
# Name: Age_Group, dtype: int64

# %%
n.plot(kind='pie')

# %%
n.plot(kind='bar')

# %% [markdown]
# ## Correlation Analysis -  Analysis Between Columns

# %%
corr = sales_data.corr()
corr
# Out:
#                      Day      Year  Customer_Age  Order_Quantity  Unit_Cost  \
# Day             1.000000 -0.007635     -0.014296       -0.002412   0.003133
# Year           -0.007635  1.000000      0.040994        0.123169  -0.217575
# Customer_Age   -0.014296  0.040994      1.000000        0.026887  -0.021374
# Order_Quantity -0.002412  0.123169      0.026887        1.000000  -0.515835
# Unit_Cost       0.003133 -0.217575     -0.021374       -0.515835   1.000000
# Unit_Price      0.003207 -0.213673     -0.020262       -0.515925   0.997894
# Profit          0.004623 -0.181525      0.004319       -0.238863   0.741020
# Cost            0.003329 -0.215604     -0.016013       -0.340382   0.829869
# Revenue         0.003853 -0.208673     -0.009326       -0.312895   0.817865
#
#                 Unit_Price    Profit      Cost   Revenue
# Day               0.003207  0.004623  0.003329  0.003853
# Year             -0.213673 -0.181525 -0.215604 -0.208673
# ...

# %% [markdown]
# #### Visualize Correlation

# %%
fig = plt.figure(figsize=(10,10))
plt.matshow(corr, cmap='cool', fignum=fig.number)
plt.xticks(range(len(corr.columns)), corr.columns, rotation='vertical')
plt.xticks(range(len(corr.columns)), corr.columns)
# Out:
# ([<matplotlib.axis.XTick at 0x7fb70eaddc10>,
# ...
#  [Text(0, 1, 'Day'),
#   Text(0, 1, 'Year'),
#   Text(0, 1, 'Customer_Age'),
#   Text(0, 1, 'Order_Quantity'),
#   Text(0, 1, 'Unit_Cost'),
#   Text(0, 1, 'Unit_Price'),
#   Text(0, 1, 'Profit'),
#   Text(0, 1, 'Cost'),
#   Text(0, 1, 'Revenue')])

# %%
sales_data.plot(kind='scatter', x='Customer_Age', y='Revenue')

# %%
sales_data.plot(kind='scatter', x='Revenue', y='Profit')

# %%
ax = sales_data[['Profit', 'Age_Group']].boxplot(by='Age_Group')

# %%
boxplot_cols=['Year', 'Customer_Age', 'Order_Quantity', 'Unit_Cost', 'Unit_Price', 'Profit']
sales_data[boxplot_cols].plot(
    kind='box', 
    subplots=True, 
    layout=(2,3), 
    figsize=(14,8)
)
# Out:
# Year                 AxesSubplot(0.125,0.536818;0.227941x0.343182)
# Customer_Age      AxesSubplot(0.398529,0.536818;0.227941x0.343182)
# Order_Quantity    AxesSubplot(0.672059,0.536818;0.227941x0.343182)
# Unit_Cost               AxesSubplot(0.125,0.125;0.227941x0.343182)
# Unit_Price           AxesSubplot(0.398529,0.125;0.227941x0.343182)
# Profit               AxesSubplot(0.672059,0.125;0.227941x0.343182)
# dtype: object

# %% [markdown]
# ## Column Wrangling

# %% [markdown]
# ### Add

# %% [markdown]
# #### Add and Calculate new `Revenue_per_Age` columm

# %%
sales_data['Revenue_per_Age'] = sales_data['Revenue']/sales_data['Customer_Age']

sales_data['Revenue_per_Age'].head()
# Out:
# 0    50.000000
# 1    50.000000
# 2    49.000000
# 3    42.612245
# 4     8.893617
# Name: Revenue_per_Age, dtype: float64

# %%
sales_data['Revenue_per_Age'].plot(kind='density')

# %%
sales_data['Revenue_per_Age'].plot(kind='hist')

# %% [markdown]
# #### Add and Calculate new `Calculated_Cost` columm and Compare it to pre-existing `Cost` Column

# %%
sales_data['Calculated_Cost'] = sales_data['Order_Quantity'] * sales_data['Customer_Age']
sales_data['Calculated_Cost'].head()
# Out:
# 0     152
# 1     152
# 2    1127
# 3     980
# 4     188
# Name: Calculated_Cost, dtype: int64

# %%
(sales_data['Calculated_Cost'] != sales_data['Cost']).sum()
# Out:
# 112750

# %% [markdown]
# #### Modify `Unit_Prince`, adding 3% Tax

# %%
sales_data['Unit_Price'].head()
# Out:
# 0    120
# 1    120
# 2    120
# 3    120
# 4    120
# Name: Unit_Price, dtype: int64

# %%
sales_data['Unit_Price'] *= 1.03

# %%
sales_data['Unit_Price'].head()
# Out:
# 0    123.6
# 1    123.6
# 2    123.6
# 3    123.6
# 4    123.6
# Name: Unit_Price, dtype: float64

# %% [markdown]
# ## Selection and Indexing

# %% [markdown]
# #### Get all sales from `Kentucky`

# %%
sales_data.loc[sales_data['State'] == 'Kentucky']
# Out:
#             Date  Day     Month  Year  Customer_Age       Age_Group  \
# 156   2013-11-04    4  November  2013            40  Adults (35-64)
# 157   2015-11-04    4  November  2015            40  Adults (35-64)
# 23826 2014-04-16   16     April  2014            40  Adults (35-64)
# 23827 2016-04-16   16     April  2016            40  Adults (35-64)
# 31446 2014-04-16   16     April  2014            40  Adults (35-64)
# 31447 2016-04-16   16     April  2016            40  Adults (35-64)
# 79670 2014-04-16   16     April  2014            40  Adults (35-64)
# 79671 2014-04-16   16     April  2014            40  Adults (35-64)
# 79672 2016-04-16   16     April  2016            40  Adults (35-64)
# 79673 2016-04-16   16     April  2016            40  Adults (35-64)
#
#       Customer_Gender        Country     State Product_Category  \
# 156                 M  United States  Kentucky      Accessories
# 157                 M  United States  Kentucky      Accessories
# ...

# %% [markdown]
# #### Get mean revenue of the `Adults (35-64)` sales group

# %%
sales_data.loc[sales_data['Age_Group'] == 'Adults (35-64)', 'Revenue'].mean()
# Out:
# 762.8287654055604

# %% [markdown]
# # Reading Data from Database

# %% [markdown]
# ## The Sakilla Database
# Sakilla Database, originally created by MySQL is an now Open-Sourced  BSD-Licensed database.

# %%
import sqlite3

# %%
conn = sqlite3.connect('FreeCodeCamp-Pandas-Real-Life-Example-master/data/sakila.db')

df = pd.read_sql('''
    SELECT
        rental.rental_id, rental.rental_date, rental.return_date,
        customer.last_name AS customer_lastname,
        store.store_id,
        city.city AS rental_store_city,
        film.title AS film_title, film.rental_duration AS film_rental_duration,
        film.rental_rate AS film_rental_rate, film.replacement_cost AS film_replacement_cost,
        film.rating AS film_rating
    FROM rental
    INNER JOIN customer ON rental.customer_id == customer.customer_id
    INNER JOIN inventory ON rental.inventory_id == inventory.inventory_id
    INNER JOIN store ON inventory.store_id == store.store_id
    INNER JOIN address ON store.address_id == address.address_id
    INNER JOIN city ON address.city_id == city.city_id
    INNER JOIN film ON inventory.film_id == film.film_id
    ;
''', conn, index_col='rental_id', parse_dates=['rental_date', 'return_date'])

# %%
df.head()
# Out:
#                   rental_date         return_date customer_lastname  store_id  \
# rental_id
# 1         2005-05-24 22:53:30 2005-05-26 22:04:30            HUNTER         1
# 2         2005-05-24 22:54:33 2005-05-28 19:40:33           COLLAZO         2
# 3         2005-05-24 23:03:39 2005-06-01 22:12:39           MURRELL         2
# 4         2005-05-24 23:04:41 2005-06-03 01:43:41             PURDY         1
# 5         2005-05-24 23:05:21 2005-06-02 04:33:21            HANSEN         2
#
#           rental_store_city       film_title  film_rental_duration  \
# rental_id
# 1                Lethbridge  BLANKET BEVERLY                     7
# 2                 Woodridge     FREAKY POCUS                     7
# 3                 Woodridge    GRADUATE LORD                     7
# 4                Lethbridge    LOVE SUICIDES                     6
# 5                 Woodridge  IDOLS SNATCHERS                     5
#
#            film_rental_rate  film_replacement_cost film_rating
# ...

# %%
df.shape
# Out:
# (16044, 10)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 16044 entries, 1 to 16049
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   rental_date            16044 non-null  datetime64[ns]
#  1   return_date            15861 non-null  datetime64[ns]
#  2   customer_lastname      16044 non-null  object
#  3   store_id               16044 non-null  int64
#  4   rental_store_city      16044 non-null  object
#  5   film_title             16044 non-null  object
#  6   film_rental_duration   16044 non-null  int64
#  7   film_rental_rate       16044 non-null  float64
#  8   film_replacement_cost  16044 non-null  float64
#  9   film_rating            16044 non-null  object
# dtypes: datetime64[ns](2), float64(2), int64(2), object(4)
# memory usage: 1.3+ MB

# %% [markdown]
# ## Numerical Analysis and Visualisation

# %%
df['film_rental_rate'].describe()
# Out:
# count    16044.000000
# mean         2.942630
# std          1.649678
# min          0.990000
# 25%          0.990000
# 50%          2.990000
# 75%          4.990000
# max          4.990000
# Name: film_rental_rate, dtype: float64

# %%
df['film_rental_rate'].mean()
# Out:
# 2.9426302667662574

# %%
df['film_rental_rate'].median()
# Out:
# 2.99

# %%
df['film_rental_rate'].plot(kind='box', vert=False, figsize=(14,6))

# %%
df['film_rental_rate'].plot(kind='density', figsize=(14,6))

# %% [markdown]
# ## Categorical Analysis and Visualisation

# %%
df['rental_store_city'].value_counts()
# Out:
# Woodridge     8121
# Lethbridge    7923
# Name: rental_store_city, dtype: int64

# %%
df['rental_store_city'].value_counts().plot(kind='pie')

# %%
ax = df['rental_store_city'].value_counts().plot(kind='bar')
ax.set_ylabel('Number of Rentals')
# Out:
# Text(0, 0.5, 'Number of Rentals')

# %% [markdown]
# ## Column Wrangling

# %% [markdown]
# We can also create new columns or modify existing ones.

# %% [markdown]
# #### Add and Calculate a new `rental_rate_return` column

# %% [markdown]
# We want to know the rental rate of return of each firm. To do that we'll use this formula:
# $$ rental\_gain\_return = \frac{film\_rental\_rate}{film\_replacement\_cost} * 100 $$

# %%
df['rental_gain_return'] = df['film_rental_rate'] / df['film_replacement_cost'] * 100
df['rental_gain_return'].head()
# Out:
# rental_id
# 1    13.597090
# 2    17.598587
# 3    19.946631
# 4     4.502046
# 5     9.969990
# Name: rental_gain_return, dtype: float64

# %%
df['rental_gain_return'].plot(kind='density')

# %%
df['rental_gain_return'].mean()
# Out:
# 16.343824010240393

# %%
df['rental_gain_return'].median()
# Out:
# 13.597089586175537

# %%
ax = df['rental_gain_return'].plot(kind='density')
ax.axvline(df['rental_gain_return'].mean(), color='red')
ax.axvline(df['rental_gain_return'].median(), color='green')

# %% [markdown]
# > Each rental represents **13.6 %** of film cost.<br>
#
# So, **7.35** rentals are required to recover film market price (`film_replacement_cost`)

# %%
100/13.6
# Out:
# 7.352941176470589

# %% [markdown]
# While, in average, a film is rented **16.74** times.

# %%
df['film_title'].value_counts().mean()
# Out:
# 16.747390396659707

# %% [markdown]
# ## Selection & Indexing
# #### Get the rental records of the customer with lastname `HANSEN`

# %%
df.loc[df['customer_lastname'] == 'HANSEN']
# Out:
#                   rental_date         return_date customer_lastname  store_id  \
# rental_id
# 5         2005-05-24 23:05:21 2005-06-02 04:33:21            HANSEN         2
# 134       2005-05-25 21:48:41 2005-06-02 18:28:41            HANSEN         2
# 416       2005-05-27 15:02:10 2005-05-29 10:34:10            HANSEN         2
# 809       2005-05-29 19:10:20 2005-06-05 19:05:20            HANSEN         2
# 1006      2005-05-31 00:57:08 2005-06-02 22:35:08            HANSEN         2
# 1368      2005-06-15 14:27:47 2005-06-23 18:07:47            HANSEN         1
# 2603      2005-06-19 06:21:25 2005-06-26 03:19:25            HANSEN         2
# 5209      2005-07-09 11:22:39 2005-07-17 09:31:39            HANSEN         1
# 5266      2005-07-09 14:17:40 2005-07-16 10:42:40            HANSEN         2
# 5592      2005-07-10 04:26:13 2005-07-19 02:32:13            HANSEN         2
# 5635      2005-07-10 06:28:39 2005-07-17 08:35:39            HANSEN         2
# ...

# %% [markdown]
# #### Create a list of all films with the highest replacement cost

# %%
df['film_replacement_cost'].max()
# Out:
# 29.99

# %%
df.loc[df['film_replacement_cost'] == df['film_replacement_cost'].max(), 'film_title'].unique()
# Out:
# array(['IDOLS SNATCHERS', 'LAWLESS VISION', 'SONG HEDWIG',
#        'LOATHING LEGALLY', 'PATIENT SISTER', 'RESERVOIR ADAPTATION',
#        'JEEPERS WEDDING', 'GOLDFINGER SENSIBILITY', 'CHARIOTS CONSPIRACY',
#        'HONEY TIES', 'GRAFFITI LOVE', 'SLACKER LIAISONS', 'DIRTY ACE',
#        'BLINDNESS GUN', 'WYOMING STORM', 'FEUD FROGMEN', 'SALUTE APOLLO',
#        'JINGLE SAGEBRUSH', 'HILLS NEIGHBORS', 'UNCUT SUICIDES',
#        'EVERYONE CRAFT', 'FLATLINERS KILLER', 'BALLROOM MOCKINGBIRD',
#        'RIVER OUTLAW', 'ARABIA DOGMA', 'VIRGIN DAISY', 'JERICHO MULAN',
#        'SASSY PACKER', 'TRACY CIDER', 'LOVER TRUMAN', 'DOCTOR GRAIL',
#        'GILMORE BOILED', 'PRINCESS GIANT', 'CRUELTY UNFORGIVEN',
#        'REIGN GENTLEMEN', 'WEST LION', 'BONNIE HOLOCAUST', 'EARTH VISION',
#        'RANDOM GO', 'CLOCKWORK PARADISE', 'FANTASIA PARK', 'RIGHT CRANES',
#        'CUPBOARD SINNERS', 'OSCAR GOLD', 'SMILE EARRING',
#        'HOLLYWOOD ANONYMOUS', 'POSEIDON FOREVER',
# ...

# %%
df.loc[(df['film_rating'] == 'PG') | (df['film_rating'] == 'PG-13')].shape[0]
# Out:
# 6797

# %% [markdown]
# **Marker:** 30:50
