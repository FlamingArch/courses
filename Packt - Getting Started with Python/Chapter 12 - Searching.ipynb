# %% [markdown]
# Searching Algorithms are of two types:
# 1. Assuming Collection is stored
# 1. Not assuming Collection is stored

# %% [markdown]
# ## Linear Search

# %% [markdown]
# ![image.jpeg](attachment:a1799d55-8077-4a21-8148-55934da4403f.jpeg)

# %% [markdown]
# Linear search traverses the list sequentialy until the element is found.

# %% [markdown]
# ### Unordered Linar Search

# %% [markdown]
# List containing elements 60, 1, 88, 10, and 100 is an example of an unordered list.

# %% [markdown]
# To perform a search operation on it, we proceeds from first item, comparing with the search item. If not matched, next element is che This continues till we reach the last element in the list or until a match is made.

# %%
def search(unordered_list, term):
    for i in range(len(unordered_list)):
        if term == unordered_list[i]:
            return i
    return none

# %%
search(range(200), 5)
# Out:
# 5
